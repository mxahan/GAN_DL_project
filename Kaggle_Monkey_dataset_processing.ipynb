# %%
import glob
import pandas as pd
import os

# %%
trainimgdir= 'data/Kaggle_Monkey/training/'
valimgdir='data/Kaggle_Monkey/validation/'
imglabels=['n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9']

# %%
# Creating an empty Dataframe with column names only
imgLabeldf = pd.DataFrame(columns=['imgNames', 'imgpath', 'label','n0','n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9'])
 
print("Empty Dataframe ", imgLabeldf, sep='\n')
# Out:
# Empty Dataframe
# Empty DataFrame
# Columns: [imgNames, imgpath, label, n0, n1, n2, n3, n4, n5, n6, n7, n8, n9]
# Index: []

# %%
for l in imglabels:
    print('Labeling images in {} folder'.format(l))
    traindir= trainimgdir+l
    imgfiles= glob.glob(traindir+'/*.jpg')
    print('Number of images:{}'.format(len(imgfiles)))
    sorted_files=sorted(imgfiles)
    for f in sorted_files:
        fn_prefix, other= os.path.splitext(f)
        words=fn_prefix.split('/')
        imgName=words[4]
#         print(imgName)
        # Append rows in Empty Dataframe by adding dictionaries
        if l=='n0':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':0, 'n0': 1, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n1':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':1, 'n0': 0, 'n1': 1, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n2':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':2, 'n0': 0, 'n1': 0, 'n2': 1, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n3':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':3, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 1, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n4':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':4, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 1, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n5':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':5, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 1, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n6':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':6, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 1, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n7':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':7, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 1, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n8':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':8, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 1, 'n9': 0}, ignore_index=True)
        elif l=='n9':
            imgLabeldf = imgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':9, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 1}, ignore_index=True)
# Out:
# Labeling images in n0 folder
# Number of images:105
# Labeling images in n1 folder
# Number of images:111
# Labeling images in n2 folder
# Number of images:110
# Labeling images in n3 folder
# Number of images:122
# Labeling images in n4 folder
# Number of images:105
# Labeling images in n5 folder
# Number of images:113
# Labeling images in n6 folder
# Number of images:106
# Labeling images in n7 folder
# Number of images:114
# Labeling images in n8 folder
# Number of images:106
# Labeling images in n9 folder
# Number of images:104

# %%
# Creating an empty Dataframe with column names only
ValimgLabeldf = pd.DataFrame(columns=['imgNames', 'imgpath', 'label', 'n0','n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9'])
 
print("Empty Dataframe ", ValimgLabeldf, sep='\n')
# Out:
# Empty Dataframe
# Empty DataFrame
# Columns: [imgNames, imgpath, label, n0, n1, n2, n3, n4, n5, n6, n7, n8, n9]
# Index: []

# %%
for l in imglabels:
    print('Labeling images in {} folder'.format(l))
    valdir= valimgdir+l
    imgfiles= glob.glob(valdir+'/*.jpg')
    print('Number of images:{}'.format(len(imgfiles)))
    sorted_files=sorted(imgfiles)
    for f in sorted_files:
        fn_prefix, other= os.path.splitext(f)
        words=fn_prefix.split('/')
        imgName=words[4]
#         print(imgName)
        # Append rows in Empty Dataframe by adding dictionaries
        if l=='n0':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':0, 'n0': 1, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n1':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':1, 'n0': 0, 'n1': 1, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n2':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':2, 'n0': 0, 'n1': 0, 'n2': 1, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n3':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':3, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 1, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n4':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':4, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 1, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n5':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':5, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 1, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n6':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':6, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 1, 'n7': 0, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n7':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':7, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 1, 'n8': 0, 'n9': 0}, ignore_index=True)
        elif l=='n8':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':8, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 1, 'n9': 0}, ignore_index=True)
        elif l=='n9':
            ValimgLabeldf = ValimgLabeldf.append({'imgNames': imgName, 'imgpath':f, 'label':9, 'n0': 0, 'n1': 0, 'n2': 0, 'n3': 0, 'n4': 0, 'n5': 0, 'n6': 0, 'n7': 0, 'n8': 0, 'n9': 1}, ignore_index=True)
# Out:
# Labeling images in n0 folder
# Number of images:26
# Labeling images in n1 folder
# Number of images:28
# Labeling images in n2 folder
# Number of images:27
# Labeling images in n3 folder
# Number of images:30
# Labeling images in n4 folder
# Number of images:26
# Labeling images in n5 folder
# Number of images:28
# Labeling images in n6 folder
# Number of images:26
# Labeling images in n7 folder
# Number of images:28
# Labeling images in n8 folder
# Number of images:27
# Labeling images in n9 folder
# Number of images:26

# %%
imgLabeldf.iloc[104:200].head()
# Out:
#     imgNames                                   imgpath label n0 n1 n2 n3 n4  \
# 104     n019   data/Kaggle_Monkey/training/n0/n019.jpg     0  1  0  0  0  0
# 105    n1017  data/Kaggle_Monkey/training/n1/n1017.jpg     1  0  1  0  0  0
# 106    n1018  data/Kaggle_Monkey/training/n1/n1018.jpg     1  0  1  0  0  0
# 107    n1019  data/Kaggle_Monkey/training/n1/n1019.jpg     1  0  1  0  0  0
# 108    n1021  data/Kaggle_Monkey/training/n1/n1021.jpg     1  0  1  0  0  0
#
#     n5 n6 n7 n8 n9
# 104  0  0  0  0  0
# 105  0  0  0  0  0
# 106  0  0  0  0  0
# 107  0  0  0  0  0
# 108  0  0  0  0  0

# %%
ValimgLabeldf.iloc[104:200].head()
# Out:
#     imgNames                                    imgpath label n0 n1 n2 n3 n4  \
# 104     n313  data/Kaggle_Monkey/validation/n3/n313.jpg     3  0  0  0  1  0
# 105     n314  data/Kaggle_Monkey/validation/n3/n314.jpg     3  0  0  0  1  0
# 106     n315  data/Kaggle_Monkey/validation/n3/n315.jpg     3  0  0  0  1  0
# 107     n316  data/Kaggle_Monkey/validation/n3/n316.jpg     3  0  0  0  1  0
# 108     n317  data/Kaggle_Monkey/validation/n3/n317.jpg     3  0  0  0  1  0
#
#     n5 n6 n7 n8 n9
# 104  0  0  0  0  0
# 105  0  0  0  0  0
# 106  0  0  0  0  0
# 107  0  0  0  0  0
# 108  0  0  0  0  0

# %%
imgLabeldf.to_csv(trainimgdir+'train_labels.csv')

# %%
ValimgLabeldf.to_csv(valimgdir+'val_labels.csv')
